# %% [markdown]
# # Lab 1: Transformer Architecture Basics
#
# ## Objective
# Understand the key components of the Transformer architecture.
#
# ## Learning Goals
# - Explore model architecture
# - Visualize attention patterns
# - Understand model parameters
# - Compare different model sizes

# %%
# Import libraries
from transformers import AutoModel, AutoTokenizer, AutoConfig
import torch
import matplotlib.pyplot as plt
import numpy as np

print(f"PyTorch version: {torch.__version__}")

# %% [markdown]
# ## Part 1: Model Architecture Inspection

# %%
# TODO: Load a model and examine its architecture
model_name = "distilgpt2"

# Your code here

# %% [markdown]
# ## Part 2: Attention Visualization

# %%
# TODO: Visualize attention patterns
# Your code here

# %% [markdown]
# ## Part 3: Model Comparison

# %%
# TODO: Compare different model sizes
# Your code here
