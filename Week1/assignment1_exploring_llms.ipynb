# %% [markdown]
# # Assignment 1: Exploring Pre-trained LLMs
#
# ## Objective
# Get familiar with loading and using pre-trained Large Language Models from Hugging Face.
#
# ## Learning Goals
# - Load pre-trained models using Transformers library
# - Understand tokenization
# - Experiment with text generation
# - Compare different model outputs

# %% [markdown]
# ## Setup
#
# First, let's import the necessary libraries.

# %%
# Import required libraries
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import torch

# Check if GPU is available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# %% [markdown]
# ## Task 1: Load a Pre-trained Model
#
# Load a small pre-trained model (e.g., distilgpt2) and tokenizer.

# %%
# TODO: Load the model and tokenizer
model_name = "distilgpt2"

# Your code here
# tokenizer = ...
# model = ...

# %% [markdown]
# ## Task 2: Understand Tokenization
#
# Explore how text is tokenized by the model.

# %%
# TODO: Tokenize a sample text and examine the tokens
sample_text = "Generative AI is transforming the world."

# Your code here

# %% [markdown]
# ## Task 3: Generate Text
#
# Use the model to generate text from a prompt.

# %%
# TODO: Generate text using different prompts
prompt = "The future of artificial intelligence is"

# Your code here

# %% [markdown]
# ## Task 4: Experiment with Generation Parameters
#
# Try different generation parameters like temperature, top_k, top_p.

# %%
# TODO: Experiment with generation parameters
# Your code here

# %% [markdown]
# ## Questions to Answer
#
# 1. How does the tokenizer handle special characters and spaces?
# 2. What is the vocabulary size of the model?
# 3. How does temperature affect the generated text?
# 4. What are the differences between greedy decoding and sampling?
#
# **Your answers:**
#
# 1.
# 2.
# 3.
# 4.

# %% [markdown]
# ## Conclusion
#
# Summarize what you learned from this assignment.
