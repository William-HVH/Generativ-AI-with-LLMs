# %% [markdown]
# # Lab 2: Fine-tuning with PEFT (LoRA)
#
# ## Objective
# Learn to fine-tune LLMs efficiently using Parameter-Efficient Fine-Tuning techniques.
#
# ## Learning Goals
# - Prepare datasets for fine-tuning
# - Apply LoRA for efficient fine-tuning
# - Evaluate fine-tuned models
# - Compare PEFT vs full fine-tuning

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, TrainingArguments, Trainer
from peft import LoraConfig, get_peft_model, TaskType
from datasets import load_dataset
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# %% [markdown]
# ## Part 1: Load and Prepare Dataset

# %%
# TODO: Load a dataset for fine-tuning
# Your code here

# %% [markdown]
# ## Part 2: Configure LoRA

# %%
# TODO: Configure LoRA parameters
# Your code here

# %% [markdown]
# ## Part 3: Fine-tune the Model

# %%
# TODO: Set up training and fine-tune
# Your code here

# %% [markdown]
# ## Part 4: Evaluate the Model

# %%
# TODO: Evaluate the fine-tuned model
# Your code here

# %% [markdown]
# ## Analysis Questions
#
# 1. How many parameters are trainable with LoRA vs full fine-tuning?
# 2. What is the trade-off between model quality and training efficiency?
# 3. How does the choice of LoRA rank (r) affect performance?
#
# **Your answers:**
#
# 1.
# 2.
# 3.
