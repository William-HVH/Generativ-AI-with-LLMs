# %% [markdown]
# # Assignment 2: Prompt Engineering
#
# ## Objective
# Master various prompt engineering techniques to improve LLM performance.
#
# ## Learning Goals
# - Design effective prompts
# - Implement zero-shot and few-shot learning
# - Apply chain-of-thought prompting
# - Evaluate prompt effectiveness

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# %% [markdown]
# ## Task 1: Zero-shot Learning
#
# Test the model's ability to perform tasks without examples.

# %%
# TODO: Create zero-shot prompts for different tasks
# Tasks: classification, summarization, translation

# Your code here

# %% [markdown]
# ## Task 2: Few-shot Learning
#
# Provide examples to guide the model.

# %%
# TODO: Create few-shot prompts with examples
# Your code here

# %% [markdown]
# ## Task 3: Chain-of-Thought Prompting
#
# Use step-by-step reasoning in prompts.

# %%
# TODO: Implement chain-of-thought prompting
# Your code here

# %% [markdown]
# ## Task 4: Prompt Evaluation
#
# Compare different prompt strategies.

# %%
# TODO: Evaluate and compare prompts
# Your code here

# %% [markdown]
# ## Questions
#
# 1. What are the key differences between zero-shot and few-shot learning?
# 2. When is chain-of-thought prompting most effective?
# 3. How does prompt structure affect output quality?
#
# **Your answers:**
#
# 1.
# 2.
# 3.
