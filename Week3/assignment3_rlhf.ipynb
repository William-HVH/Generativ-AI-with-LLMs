# %% [markdown]
# # Assignment 3: RLHF and Model Alignment
#
# ## Objective
# Understand Reinforcement Learning from Human Feedback and model alignment concepts.
#
# ## Learning Goals
# - Understand reward models
# - Explore PPO (Proximal Policy Optimization)
# - Analyze alignment techniques
# - Compare aligned vs non-aligned models

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# %% [markdown]
# ## Task 1: Understanding Reward Models
#
# Explore how reward models work in RLHF.

# %%
# TODO: Implement a simple reward model concept
# Your code here

# %% [markdown]
# ## Task 2: Model Alignment Comparison
#
# Compare outputs from aligned and non-aligned models.

# %%
# TODO: Compare model outputs
# Your code here

# %% [markdown]
# ## Task 3: Analyzing RLHF Benefits
#
# Test models on various prompts to see alignment effects.

# %%
# TODO: Test with different prompts
# Your code here

# %% [markdown]
# ## Questions
#
# 1. What are the main components of RLHF?
# 2. Why is model alignment important?
# 3. What challenges exist in RLHF training?
#
# **Your answers:**
#
# 1.
# 2.
# 3.
